# %%
import get_data as gd
import pandas as pd
import requests
import mdax as md
import os

print("getting MDAX symbols")
mda = md.mdax()

print(mda)
# Out:
# getting MDAX symbols
# ...

# %%
mda.mdaxData.xs('FRE.DE', level=1, axis=1)
# Out:
#             Adj Close  Close   High    Low   Open     Volume
# Date
# 2009-01-02       8.45  11.83  12.33  11.39  12.33   163248.0
# 2009-01-05       8.21  11.49  12.00  11.30  12.00   119121.0
# 2009-01-06       8.49  11.88  12.00  11.54  11.57   121272.0
# 2009-01-07       8.11  11.35  11.88  11.30  11.88   202644.0
# 2009-01-08       7.81  10.93  11.37  10.90  11.36   206439.0
# 2009-01-09       7.92  11.09  11.36  10.88  11.01   113103.0
# 2009-01-12       7.91  11.06  11.31  10.89  11.14   217122.0
# 2009-01-13       8.12  11.36  11.43  10.87  11.11   403140.0
# 2009-01-14       8.34  11.67  11.75  11.42  11.51   136893.0
# 2009-01-15       8.02  11.22  11.67  11.10  11.45   159774.0
# 2009-01-16       7.98  11.17  11.64  11.05  11.47   124107.0
# 2009-01-19       8.22  11.50  11.88  11.22  11.22   119934.0
# 2009-01-20       8.23  11.52  11.93  11.36  11.42   128595.0
# 2009-01-21       8.01  11.21  11.48  11.08  11.31   213510.0
# ...

# %%
mda.mdaxData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2664 entries, 2009-01-02 to 2019-06-07
# Columns: 174 entries, (Adj Close, 1COV.DE) to (Volume, WDI.DE)
# dtypes: float64(174)
# memory usage: 3.6 MB
